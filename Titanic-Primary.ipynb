# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.0.2

# %%
import os
print(os.listdir("/kaggle/input/datasets/shuofxz/titanic-machine-learning-from-disaster"))
# Out:
# ['train.csv', 'test.csv']

# %%
df = pd.read_csv("/kaggle/input/datasets/shuofxz/titanic-machine-learning-from-disaster/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Data Dictionary:****
# # **Variable	   Definition	                      Key****
#   survival	       Survival	                     0 = No, 1 = Yes
#   pclass	       Ticket class	                 1 = 1st, 2 = 2nd, 3 = 3rd
#    sex	             Sex
#    Age	           Age in years
#   sibsp	           # of siblings / spouses aboard the Titanic
#   parch	           # of parents / children aboard the Titanic
#   ticket	       Ticket number
#   fare	           Passenger fare
#   cabin	           Cabin number
#   embarked	      Port of Embarkation	         C = Cherbourg, Q = Queenstown, S = Southampton
#
#
# # Data Dictionary
#
# * pclass: A proxy for socio-economic status (SES)
#
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
# * age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# * sibsp: The dataset defines family relations in this way...
#
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
# parch: The dataset defines family relations in this way...
#
# * Parent = mother, father
#  Child = daughter, son, stepdaughter, stepson
#  Some children travelled only with a nanny, therefore parch=0 for them.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Cabin"].value_counts().sum()
# Out:
# np.int64(204)

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
df.groupby("Pclass")["Survived"].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
df.groupby("Sex")["Survived"].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df.groupby("SibSp")["Survived"].value_counts()
# Out:
# SibSp  Survived
# 0      0           398
#        1           210
# 1      1           112
#        0            97
# 2      0            15
#        1            13
# 3      0            12
#        1             4
# 4      0            15
#        1             3
# 5      0             5
# 8      0             7
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='object')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %% [markdown]
# # Notes:
#
# PassengerId is useless, we will drop it
# Pclass : we can consider it categorical by native ( We may change its dtype)
# Sex: Males Count is bigger than Females Count
# Embarked: 'S' City is the most frequent value

# %%
df.drop(["PassengerId", "Ticket", "Cabin"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
df = df[['Name', 'Sex',	'Age', 'SibSp',	'Parch', 'Fare', 'Embarked', 'Pclass', 'Survived']]
df.head()
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Pclass  Survived
# 0      0   7.2500        S       3         0
# 1      0  71.2833        C       1         1
# 2      0   7.9250        S       3         1
# 3      0  53.1000        S       1         1
# 4      0   8.0500        S       3         0

# %%
df.isna().sum()
# Out:
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Pclass        0
# Survived      0
# dtype: int64

# %%
df.shape
# Out:
# (891, 9)

# %%
df1=df.copy()
df1
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked  Pclass  Survived
# ...

# %%
df1["Age"]=df1["Age"].fillna(df1["Age"].mean())
df1
# Out:
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch     Fare Embarked  Pclass  Survived
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      891 non-null    object
#  1   Sex       891 non-null    object
#  2   Age       891 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Embarked  889 non-null    object
#  7   Pclass    891 non-null    int64
#  8   Survived  891 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df1.shape
# Out:
# (891, 9)

# %%
df1["Embarked"]=df1["Embarked"].fillna(df1["Embarked"].mode()[0])
df1
# Out:
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch     Fare Embarked  Pclass  Survived
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      891 non-null    object
#  1   Sex       891 non-null    object
#  2   Age       891 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Embarked  891 non-null    object
#  7   Pclass    891 non-null    int64
#  8   Survived  891 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df1.shape
# Out:
# (891, 9)

# %%
df1["Sex"]=df1["Sex"].replace(["male","female"],[0,1])
df1
# Out:
# /tmp/ipykernel_17/2505542029.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["Sex"]=df1["Sex"].replace(["male","female"],[0,1])
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ..                                                 ...  ...        ...    ...
# ...

# %%
df1.head()
# Out:
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare Embarked  Pclass  Survived
# 0   7.2500        S       3         0
# 1  71.2833        C       1         1
# 2   7.9250        S       3         1
# 3  53.1000        S       1         1
# 4   8.0500        S       3         0

# %%
df1["Sex"].value_counts()
# Out:
# Sex
# 0    577
# 1    314
# Name: count, dtype: int64

# %%
df2=df1.copy()
df2
# Out:
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ..                                                 ...  ...        ...    ...
# 886                              Montvila, Rev. Juozas    0  27.000000      0
# 887                       Graham, Miss. Margaret Edith    1  19.000000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1  29.699118      1
# 889                              Behr, Mr. Karl Howell    0  26.000000      0
# 890                                Dooley, Mr. Patrick    0  32.000000      0
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      891 non-null    object
#  1   Sex       891 non-null    int64
#  2   Age       891 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Embarked  891 non-null    object
#  7   Pclass    891 non-null    int64
#  8   Survived  891 non-null    int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
df2["Embarked"].nunique()
# Out:
# 3

# %%
df2["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df2["Embarked"].unique().tolist()
# Out:
# ['S', 'C', 'Q']

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %% [markdown]
# from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # ****Label Encoding******

# %%
le=LabelEncoder()

# %%
df2.head()
# Out:
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare Embarked  Pclass  Survived
# 0   7.2500        S       3         0
# 1  71.2833        C       1         1
# 2   7.9250        S       3         1
# 3  53.1000        S       1         1
# 4   8.0500        S       3         0

# %%
df2["Embarked"]=le.fit_transform(df2["Embarked"])

# %%
df2.head()
# Out:
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare  Embarked  Pclass  Survived
# 0   7.2500         2       3         0
# 1  71.2833         0       1         1
# 2   7.9250         2       3         1
# 3  53.1000         2       1         1
# 4   8.0500         2       3         0

# %% [markdown]
# # ****Ordinal Encoding****

# %%
ord=OrdinalEncoder()

# %%
df2["Embarked"]=ord.fit_transform(df2[["Embarked"]])

# %%
df2.head()
# Out:
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare  Embarked  Pclass  Survived
# 0   7.2500       2.0       3         0
# 1  71.2833       0.0       1         1
# 2   7.9250       2.0       3         1
# 3  53.1000       2.0       1         1
# 4   8.0500       2.0       3         0

# %%
df3=df.copy()
df3
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked  Pclass  Survived
# ...

# %%
df3["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df3["Sex"].nunique()
# Out:
# 2

# %%
df3["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df3["Sex"].unique().tolist()
# Out:
# ['male', 'female']

# %%
encode=le.fit(df3["Sex"])
df3.head()
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Pclass  Survived
# 0      0   7.2500        S       3         0
# 1      0  71.2833        C       1         1
# 2      0   7.9250        S       3         1
# 3      0  53.1000        S       1         1
# 4      0   8.0500        S       3         0

# %%
df3["Sex"]=encode.transform(df3["Sex"])
df3.head()
# Out:
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#       Fare Embarked  Pclass  Survived
# 0   7.2500        S       3         0
# 1  71.2833        C       1         1
# 2   7.9250        S       3         1
# 3  53.1000        S       1         1
# 4   8.0500        S       3         0

# %%
df4=df.copy()
df4
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked  Pclass  Survived
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      891 non-null    object
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Embarked  889 non-null    object
#  7   Pclass    891 non-null    int64
#  8   Survived  891 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df4.columns
# Out:
# Index(['Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Pclass',
#        'Survived'],
#       dtype='object')

# %% [markdown]
# #Homework
# **using loop for Label Encoding**

# %%
from numpy._core.defchararray import count
from pandas.api.types import is_numeric_dtype

# %%
le = LabelEncoder()

# %%
for col in df4.columns:
    if not is_numeric_dtype(df4[col]):
        df4[col]=le.fit_transform(df4[col])

# %%
df4.head()
# Out:
#    Name  Sex   Age  SibSp  Parch     Fare  Embarked  Pclass  Survived
# 0   108    1  22.0      1      0   7.2500         2       3         0
# 1   190    0  38.0      1      0  71.2833         0       1         1
# 2   353    0  26.0      0      0   7.9250         2       3         1
# 3   272    0  35.0      1      0  53.1000         2       1         1
# 4    15    1  35.0      0      0   8.0500         2       3         0

# %%
df4["Sex"].value_counts()
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
df4["Embarked"].value_counts()
# Out:
# Embarked
# 2    644
# 0    168
# 1     77
# 3      2
# Name: count, dtype: int64

# %% [markdown]
# ** ******#**** OneHotEncoding**** **

# %%
df5=df.copy()
df5
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked  Pclass  Survived
# ...

# %%
one=OneHotEncoder(sparse_output=False)

# %%
dummy=pd.get_dummies(df5["Embarked"])
dummy
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [891 rows x 3 columns]

# %%
dummy=pd.get_dummies(df5["Embarked"]).astype("int64")
dummy
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
dummy=pd.get_dummies(df5["Embarked"], drop_first=True).astype("int64")
dummy
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       891 non-null    int64
#  1   S       891 non-null    int64
# dtypes: int64(2)
# memory usage: 14.1 KB

# %%
dummy=pd.get_dummies(df5["Embarked"], drop_first=True, prefix="Embarked").astype("int64")
dummy
# Out:
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 2 columns]

# %%
df5=df5.drop(["Embarked"],axis=1)
df5
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare  Pclass  Survived
# ...

# %%
df5=pd.concat([df5,dummy],axis=1)
df5.head()
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare  Pclass  Survived  Embarked_Q  Embarked_S
# 0      0   7.2500       3         0           0           1
# 1      0  71.2833       1         1           0           0
# 2      0   7.9250       3         1           0           1
# 3      0  53.1000       1         1           0           1
# 4      0   8.0500       3         0           0           1

# %% [markdown]
# # OneHitEncoding-Another Method#

# %%
df5["Sex"]=one.fit_transform(df5[["Sex"]])
df5
# Out:
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  1.0  38.0      1
# 2                               Heikkinen, Miss. Laina  1.0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1
# 4                             Allen, Mr. William Henry  0.0  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas  0.0  27.0      0
# 887                       Graham, Miss. Margaret Edith  1.0  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  1.0   NaN      1
# 889                              Behr, Mr. Karl Howell  0.0  26.0      0
# 890                                Dooley, Mr. Patrick  0.0  32.0      0
#
#      Parch     Fare  Pclass  Survived  Embarked_Q  Embarked_S
# ...

# %%
df5["Sex"].value_counts()
# Out:
# Sex
# 0.0    577
# 1.0    314
# Name: count, dtype: int64

# %% [markdown]
# Homework
# # ****Loop Method - OnehotEncoding# # #

# %%
df6=df.copy()
df6
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked  Pclass  Survived
# ...

# %%
for col in df6.columns:
    if not is_numeric_dtype(df6[col]):
        df6[col]=one.fit_transform(df6[[col]])

# %%
df6.head()
# Out:
#    Name  Sex   Age  SibSp  Parch     Fare  Embarked  Pclass  Survived
# 0   0.0  0.0  22.0      1      0   7.2500       0.0       3         0
# 1   0.0  1.0  38.0      1      0  71.2833       1.0       1         1
# 2   0.0  1.0  26.0      0      0   7.9250       0.0       3         1
# 3   0.0  1.0  35.0      1      0  53.1000       0.0       1         1
# 4   0.0  0.0  35.0      0      0   8.0500       0.0       3         0
